# %%
import cv2
import lbg
import compression
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # 1) Effect on the codebook size

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation1/'
# %time compression.sim_protocol(img, 16, 0.0005, (8,8), root, '512_16_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 15.4 s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation1/'
# %time compression.sim_protocol(img, 32, 0.0005, (8,8), root, '512_32_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 36.7 s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation1/'
# %time compression.sim_protocol(img, 64, 0.0005, (8,8), root, '512_64_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 1min 4s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation1/'
# %time compression.sim_protocol(img, 128, 0.0005, (8,8), root, '512_128_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 2min 1s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation1/'
# %time compression.sim_protocol(img, 256, 0.0005, (8,8), root, '512_256_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 3min 57s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation1/'
# %time compression.sim_protocol(img, 512, 0.0005, (8,8), root, '512_512_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 6min 19s

# %% [markdown]
# # 2) Effect on different epsilon (threshold)

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation2/'
# %time compression.sim_protocol(img, 64, 0.005, (8,8), root, '512_64_0.005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 37.6 s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation2/'
# %time compression.sim_protocol(img, 64, 0.0005, (8,8), root, '512_64_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 1min 4s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation2/'
# %time compression.sim_protocol(img, 64, 0.00005, (8,8), root, '512_64_0.00005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 1min 28s

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation2/'
# %time compression.sim_protocol(img, 64, 0.00001, (8,8), root, '512_64_0.00001')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 1min 45s

# %% [markdown]
# # 3) Effect on the block size

# %%
img = cv2.imread('./images/Lenna1024.png', cv2.IMREAD_GRAYSCALE)
root = './simulation3/'
# %time compression.sim_protocol(img, 64, 0.0005, (2,2), root, '1024_64_2_0.0005')
# Out:
# (512, 512)
# (1024, 1024)
# Wall time: 1h 28min 23s

# %%
img = cv2.imread('./images/Lenna1024.png', cv2.IMREAD_GRAYSCALE)
root = './simulation3/'
# %time compression.sim_protocol(img, 64, 0.0005, (4,4), root, '1024_64_4_0.0005')
# Out:
# (256, 256)
# (1024, 1024)
# Wall time: 24min 57s

# %%
img = cv2.imread('./images/Lenna1024.png', cv2.IMREAD_GRAYSCALE)
root = './simulation3/'
# %time compression.sim_protocol(img, 64, 0.0005, (8,8), root, '1024_64_8_0.0005')
# Out:
# (128, 128)
# (1024, 1024)
# Wall time: 7min 16s

# %%
img = cv2.imread('./images/Lenna1024.png', cv2.IMREAD_GRAYSCALE)
root = './simulation3/'
# %time compression.sim_protocol(img, 64, 0.0005, (16,16), root, '1024_64_16_0.0005')
# Out:
# (64, 64)
# (1024, 1024)
# Wall time: 2min 2s

# %% [markdown]
# # 4) Using other image as Training and use the codebook for different image

# %%
img = cv2.imread('./images/Lenna512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation4/'
# %time compression.sim_protocol(img, 256, 0.0005, (8,8), root, 'Lenna_512_256_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 4min 11s

# %%
img = cv2.imread('./images/Barbara512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation4/'
# %time compression.sim_protocol(img, 256, 0.0005, (8,8), root, 'Barbara_512_256_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 4min 9s

# %%
img = cv2.imread('./images/Boat512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation4/'
# %time compression.sim_protocol(img, 256, 0.0005, (8,8), root, 'Boat_512_256_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 3min 40s

# %%
img = cv2.imread('./images/Cameraman512.png', cv2.IMREAD_GRAYSCALE)
root = './simulation4/'
# %time compression.sim_protocol(img, 256, 0.0005, (8,8), root, 'Cameraman_512_256_0.0005')
# Out:
# (64, 64)
# (512, 512)
# Wall time: 4min 3s

# %% [markdown]
# # 5) Use more than one image to Train

# %%
root = './simulation5/'
# %time compression.sim_multi_protocol(['./images/Lenna512.png', './images/Barbara512.png'], 64, 0.0005, (8,8), root, 'Lenna_Barbara_64_8_0.0005')
# Out:
# Weight Saved as: Lenna_Barbara_64_8_0.0005
# Wall time: 2min 10s

# %%
root = './simulation5/'
# %time compression.sim_multi_protocol(['./images/Lenna512.png', './images/Barbara512.png', './images/Boat512.png'], 64, 0.0005, (8,8), root, 'Lenna_Barbara_Boat_64_8_0.0005')
# Out:
# Weight Saved as: Lenna_Barbara_Boat_64_8_0.0005
# Wall time: 3min 22s

# %%
root = './simulation5/'
# %time compression.sim_multi_protocol(['./images/Lenna512.png', './images/Barbara512.png', './images/Boat512.png', './images/Cameraman512.png'], 64, 0.0005, (8,8), root, 'Lenna_Barbara_Boat_Cameraman_64_8_0.0005')
# Out:
# Weight Saved as: Lenna_Barbara_Boat_Cameraman_64_8_0.0005
# Wall time: 4min 13s

# %% [markdown]
# # 6) Best image as training image

# %% [markdown]
# ### This section will be proven by trying One by one of the weight which we have been done in section 4.
